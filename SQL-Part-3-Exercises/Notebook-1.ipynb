-- %% [markdown]
-- # SQL Part 3 Exercises Joins
--
-- This notebook works with the BooksDB dataset.
--
-- **Questions 1-4** focus on how joins work in a more general sense.  If you are not sure how to best answer the questions, try manipulating the queries by changing the order of joins, the length of the TOP, or how they are ordered.
--
-- > <span style="background-color: rgba(127, 127, 127, 0.1);"><i>Note</i>: If some of the queries are not returning quickly, you can try closing and restarting azure data studio after a few minutes.</span>
--
-- In **questions 5-8**, you will be asked to join tables to find results about titles, tags, and the books users want to read.
--
-- As you go through the questions, you will see 'Minimum Desired Output'.  This will provide you with the bare minimum columns needed to answer the questions.  When you write the queries, add as many additional columns as you need to best find your answers.

-- %% [markdown]
-- ## **QUESTION 1:**  Exploring a LEFT JOIN using the **books** and **to\_read** tables
--
-- The code block below has been commented out. To answer this question, you will need to uncomment it by removing the **/\*** (line 1) and **\*/** (line 16).
--
-- **Part A:** Look at Query 1, which table is the 'Left' table and which is the 'Right'?
--
-- > Your Answer:  Books table is left table,to\_read right table
--
-- **Part B:** Using table 2, answer the following questions:
--
-- - When we added a  '**WHERE tr.user\_id IS NOT NULL'** clause (line 14), how did the table change?  Why?
--
-- > Your Answer: only the matched rows from 2 tables got executed

-- %%
-- Query 1: LEFT JOIN 
-- SELECT TOP 50 b.title, b.average_rating, b.books_count,tr.user_id, tr.book_id
-- FROM BooksDB.dbo.books AS b
-- LEFT JOIN BooksDB.dbo.to_read AS tr
-- ON b.best_book_id = tr.book_id
-- ORDER BY b.average_rating;

-- -- Query 2: LEFT JOIN USING 'IS NOT NULL'
SELECT TOP 50 b.title, b.average_rating, b.books_count,tr.user_id, tr.book_id
FROM BooksDB.dbo.books AS b
LEFT JOIN BooksDB.dbo.to_read AS tr
ON b.best_book_id = tr.book_id
WHERE tr.user_id IS NOT NULL
ORDER BY b.average_rating;
-- Out:
-- (50 rows affected)
-- Total execution time: 00:00:04.095
-- ...

-- %% [markdown]
-- ## **QUESTION 2:** Exploring **RIGHT** joins with the **books** and **to\_read** tables
--
-- You will need to uncomment the Query to answer the question.
--
-- **Part A:** Looking at the query, which table is the 'Left' and which is the 'Right'?
--
-- > Your Answer: books: left table, to\_read: right table
--
-- **Part B:** How do the RIGHT-joined tables differ from the LEFT-joined tables in Question 1?
--
-- > Your Answer:All the to\_read table rows got selected

-- %%
-- Query 1: RIGHT JOIN
SELECT TOP 300 b.title, b.average_rating, b.books_count, tr.user_id, tr.book_id
FROM BooksDB.dbo.books AS b
RIGHT JOIN BooksDB.dbo.to_read AS tr
ON b.best_book_id = tr.book_id;
-- Out:
-- (300 rows affected)
-- Total execution time: 00:00:00.072
-- ...

-- %% [markdown]
-- ## **QUESTION 3:** Exploring FULL JOINS with the **books** and **to\_read** tables
--
-- You will need to uncomment the Query to answer the question.
--
-- **Part A:**  Look at the table and explore how it was populated.  Try manipulating the query to better understand how this table works.  Try adding a WHERE clause, or ORDER BY a column on the **books** table.  Based on your exploration, can you think of when you might want a FULL join rather than a LEFT, RIGHT, or INNER?
--
-- > Your Answer: <span style="color: var(--tw-prose-body); font-size: 1rem; white-space: pre-wrap; background-color: rgba(247,247,248,var(--tw-bg-opacity)); font-family: Söhne, ui-sans-serif, system-ui, -apple-system, &quot;Segoe UI&quot;, Roboto, Ubuntu, Cantarell, &quot;Noto Sans&quot;, sans-serif, &quot;Helvetica Neue&quot;, Arial, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Noto Color Emoji&quot;;">A full join, also known as a full outer join, is used in situations where you want to combine the rows from both the left and right tables of a join, including matching rows and non-matching rows. In other words, it returns all rows from both tables, including those where there is no match in the other table. This type of join is less common than left, right, and inner joins, but it can be useful in specific scenarios:</span>
-- >
-- > 1. <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Including all data:</span> When you need to ensure that all rows from both tables are included in the result, regardless of whether there's a match. This can be useful when analyzing data where you don't want to miss any information.
-- >
-- > 2. <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Analyzing missing data:</span> Full joins are helpful when you want to identify missing data or analyze data discrepancies between two tables. The result of a full join will clearly show which rows exist in one table but not in the other.
-- >
-- > 3. <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Merging disparate data:</span> If you have two datasets with different sets of keys or identifiers, and you want to merge them while keeping all the available information, a full join can be used to combine them effectively.
-- >
-- > 4. <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Comparing two datasets:</span> When you want to compare two datasets based on a common identifier or key, a full join can help you identify differences and similarities between the datasets.
-- >
-- >
-- > It's important to note that full joins can lead to larger result sets, especially when dealing with large datasets, as they include all rows from both tables. This can impact performance and memory usage, so they should be used thoughtfully.
-- >
-- > In most cases, left, right, and inner joins are more commonly used because they focus on specific subsets of data:
-- >
-- > - <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Left Join:</span> Returns all rows from the left table and the matching rows from the right table. If there's no match in the right table, the result will contain NULL values for the columns from the right table.
-- >
-- > - <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Right Join:</span> Similar to a left join, but it returns all rows from the right table and the matching rows from the left table. Non-matching rows from the left table are filled with NULL values.
-- >
-- > - <span style="border: 0px solid rgb(217, 217, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600; color: var(--tw-prose-bold);">Inner Join:</span> Returns only the matching rows from both tables based on the specified join condition. Non-matching rows are excluded from the result.
-- >
-- >
-- > In summary, use a full join when you need to combine all rows from both tables, including both matches and non-matches. Use left, right, or inner joins when you want to focus on specific subsets of the data based on your analysis needs.

-- %%
-- FULL JOIN
SELECT TOP 30 b.title, b.average_rating, b.books_count,tr.user_id, tr.book_id
FROM BooksDB.dbo.books AS b
FULL JOIN BooksDB.dbo.to_read AS tr
ON b.book_id = tr.book_id;
-- Out:
-- (30 rows affected)
-- Total execution time: 00:00:00.441
-- ...

-- %% [markdown]
-- ## **QUESTION 4:** Exploring INNER Joins with the **books** and **to\_read** tables
--
-- You will need to uncomment the Query to answer the question.
--
-- **Part A:**  What does an inner join do?
--
-- > <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">Your Answer: Inner join combines 2 tables with matching rows from 2 tables</span>
--
-- <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;"><b>Part B:</b>&nbsp;Currently this table has an <b>'IS NOT NULL'</b> in the <b>WHERE</b> clause.&nbsp; Is this necessary for this table?&nbsp; Why or Why not?&nbsp;</span>
--
-- > Your Answer: It is not necessary because inner join joins only matching rows from 2 tables
--
-- **Part C:**  When using SQL, you are usually returning much larger tables so every line of code will add to the compilation and return time.  Rewrite this inner join query so that it contains no redundant code.
--
-- > Your Answer:  Update the query in the code box below.

-- %%
-- INNER JOIN
SELECT TOP 30 b.title, b.average_rating, b.books_count,tr.user_id, tr.book_id
FROM BooksDB.dbo.books AS b
INNER JOIN BooksDB.dbo.to_read AS tr
ON b.book_id = tr.book_id
ORDER BY tr.book_id;
-- Out:
-- (30 rows affected)
-- Total execution time: 00:00:00.177
-- ...

-- %% [markdown]
-- ## **QUESTION 5:**  Using joins to find the most tagged book and the most popular tag
--
-- We will be writing 3 queries to find both the most tagged book and that book's most popular tag.
--
-- **Part A:**  What is the most tagged book?
--
-- > <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">Start by joining the </span> **books** <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">and </span> **book\_tags**      <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">&nbsp;tables ON the books.best_book_id and book_tags.goodreads_book_id.&nbsp;&nbsp;<br></span>          <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">We want the <i>most popular</i> book, so think about ordering the table in a way that will display both the book title and the number of times a book tag has been used.</span>
-- >
-- > _MInimum Desired output:_  The title of the most tagged book, and the number of times the book has been tagged.
-- >
-- > **Title:**
-- >
-- > **The Alchemist 596234 30574**
--
-- **Part B:** How many different tags have been used for the most tagged book?
--
-- > <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);">Start by joining the&nbsp;</span>      **books** <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);">and&nbsp;</span>      **book\_tags**      <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);">&nbsp;tables ON the books.best_book_id and book_tags.goodreads_book_id.&nbsp;&nbsp;<br></span>          We want to find the _most popular_ tag id, so think about ordering in a way that will display the most popular tag id.
-- >
-- > <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);"><i>Minimum Desired Output:</i> The tag id for the most popular tag used for the most tagged book.&nbsp;</span>
-- >
-- > <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);"><b>Tag Id:&nbsp;</b></span>   <span style="color: var(--vscode-foreground);">30574</span>
--
-- <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);"><b>Part C: </b>What is this particular tag?</span>
--
-- > You may return this answer with a simple query.
--
-- > <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);"><i>Minimum Desired Output:</i>&nbsp;The tag name for the most popular tag used for the most tagged book.&nbsp;</span>
-- >
-- >

-- %%
select BooksDB.dbo.books.title,BooksDB.dbo.book_tags.count,BooksDB.dbo.book_tags.tag_id from BooksDB..book_tags JOIN  
BooksDB.dbo.books on BooksDB.dbo.book_tags.goodreads_book_id = BooksDB.dbo.books.book_id ORDER by BooksDB.dbo.book_tags.count DESC
-- Out:
-- (999912 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:30.614
-- ...

-- %%
select tag_name from BooksDB.dbo.tags where tag_id= 30574
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.060
-- <table><tr><th>tag_name</th></tr><tr><td>to-read</td></tr></table>

-- %% [markdown]
-- ## **QUESTION 6:** Find a book based on a tag of your choice using joins.
--
-- Some suggestions: any hobbies you like? baking, drawing, etc. how about favorite holidays, subjects, animals, etc?
--
-- **Part A:** Explore the tags table for a tag of your choice.  Suggested ideas, try searching for one of your hobbies, a favorite time of year, favorite animal, etc.  Start by querying the tag table for your chosen tag.  (_Hint:_ in order to make sure you find all combinations of your tags, use the wildcard).  If your query returns more than one result, pick your favorite.
--
-- > > _Here is an example.  Alyce wanted to search for halloween books.  She used the wildcard, '%halloween%' and 8 different combinations were found.  Alyce selected '**halloween-storytime**', with a tag id of 13877._
--
-- > _Minimum Desired Output:_ <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; background-color: rgba(127, 127, 127, 0.1);">tag name and tag id</span>
--
-- > **Your Tag and Tag Id: fantasy-humour-11352**
--
-- **Part B:** Now that you have the **tag id**, find the title that was tagged the most with this tag by joining the books and books\_tags tables.
--
-- > > _Alyce joined the book table with the tags table and discovered that <u>The Little Old Lady Who Was Not Afraid of Anything</u> was tagged as '**halloween-storytime**' the most._
--
-- > _Minimum Desired Output:_ <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">title and tag count</span>
--
-- > **Your Title and Number of times the tag was used:**

-- %%
select * from BooksDB.dbo.tags where tag_name like '%halloween%'
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.108
-- <table><tr><th>tag_id</th><th>tag_name</th></tr><tr><td>13873</td><td>halloween</td></tr><tr><td>13874</td><td>halloween-books</td></tr><tr><td>13875</td><td>halloween-reading</td></tr><tr><td>13876</td><td>halloween-reads</td></tr><tr><td>13877</td><td>halloween-storytime</td></tr><tr><td>14698</td><td>holiday-halloween</td></tr><tr><td>14706</td><td>holidays-halloween</td></tr><tr><td>28416</td><td>spooky-reads-for-halloween</td></tr></table>

-- %%
select b.title,bt.[count],bt.tag_id from BooksDB.dbo.books b INNER JOIN BooksDB.dbo.book_tags bt on bt.goodreads_book_id=b.best_book_id 
where bt.tag_id=13877
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.132
-- <table><tr><th>title</th><th>count</th><th>tag_id</th></tr><tr><td>The Little Old Lady Who Was Not Afraid of Anything</td><td>4</td><td>13877</td></tr></table>

-- %%
select BooksDB.dbo.book_tags.count,BooksDB.dbo.books.title from BooksDB.dbo.book_tags join BooksDB.dbo.books on
 BooksDB.dbo.book_tags.goodreads_book_id=BooksDB.dbo.books.book_id where BooksDB.dbo.book_tags.tag_id=11352
-- Out:
-- (34 rows affected)
-- Total execution time: 00:00:00.272
-- ...

-- %%
select

-- %% [markdown]
-- ## **QUESTION 7:** What are the top 10 most popular book titles on the 'to read' list?
--
-- **Part A:**  Explore how the **to\_read** and **books** tables are organized, and then join them.  What will you use as a key?
--
-- > Your Answer:
--
-- **Part B:** Organize your newly joined table in a way that groups popularity based on the title based on users.
--
-- > _Hint:_ Suggest using an alias for the aggregation you will need to run on the **user\_id**
--
-- > _Minimum Desired Output:_ title and aliased column

-- %%
select top 10 BooksDB.dbo.books.title,count(BooksDB.dbo.to_read.user_id )'user id'from 
BooksDB.dbo.books join BooksDB.dbo.to_read on BooksDB.dbo.books.book_id=BooksDB.dbo.to_read.book_id
group by BooksDB.dbo.books.title ORDER by count(BooksDB.dbo.to_read.user_id ) DESC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.184
-- <table><tr><th>title</th><th>user id</th></tr><tr><td>The Ultimate Hitchhiker&#39;s Guide to the Galaxy</td><td>1812</td></tr><tr><td>The Hitchhiker&#39;s Guide to the Galaxy (Hitchhiker&#39;s Guide to the Galaxy, #1)</td><td>1767</td></tr><tr><td>The Lord of the Rings: The Art of The Fellowship of the Ring</td><td>1499</td></tr><tr><td>Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)</td><td>1498</td></tr><tr><td>Harry Potter and the Goblet of Fire (Harry Potter, #4)</td><td>1484</td></tr><tr><td>The Known World</td><td>1352</td></tr><tr><td>Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)</td><td>1293</td></tr><tr><td>The Lord of the Rings: Weapons and Warfare</td><td>1211</td></tr><tr><td>Notes from a Small Island</td><td>1148</td></tr><tr><td>Harry Potter Collection (Harry Potter, #1-6)</td><td>1110</td></tr></table>

-- %% [markdown]
-- ## **QUESTION 8:** Largest 'To Read' Lists
--
-- **Part A:**  Create a query that returns a table that contains the top 10 users with the most number of titles on their 'to read' list.    Group all the entries by user\_id.
--
-- > _Hint:_ You might want an alias for the titles.
-- >
-- > _Minimum Desired Output:_  user\_id and your aliased column of titles.
--
-- **Part B:**  The longest list length is 15 titles total, and is shared by 4 different users.  Select one of the uses and print out their entire '**to read**' list.

-- %%
select top 10 count(BooksDB.dbo.books.title)'to_read',BooksDB.dbo.to_read.user_id from 
BooksDB.dbo.books join BooksDB.dbo.to_read on BooksDB.dbo.books.book_id=BooksDB.dbo.to_read.book_id
group by BooksDB.dbo.to_read.user_id ORDER by count(BooksDB.dbo.books.title ) DESC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.162
-- <table><tr><th>to_read</th><th>user_id</th></tr><tr><td>15</td><td>14771</td></tr><tr><td>15</td><td>12483</td></tr><tr><td>15</td><td>11932</td></tr><tr><td>15</td><td>38201</td></tr><tr><td>14</td><td>36923</td></tr><tr><td>14</td><td>41523</td></tr><tr><td>14</td><td>27933</td></tr><tr><td>14</td><td>37359</td></tr><tr><td>13</td><td>25734</td></tr><tr><td>13</td><td>51137</td></tr></table>

-- %%
select BooksDB.dbo.books.title'to_read',BooksDB.dbo.to_read.user_id from 
BooksDB.dbo.books join BooksDB.dbo.to_read on BooksDB.dbo.books.book_id=BooksDB.dbo.to_read.book_id 
where BooksDB.dbo.to_read.user_id='12483'
-- Out:
-- (15 rows affected)
-- Total execution time: 00:00:00.329
-- <table><tr><th>to_read</th><th>user_id</th></tr><tr><td>Fahrenheit 451</td><td>12483</td></tr><tr><td>Hamlet</td><td>12483</td></tr><tr><td>Great Expectations</td><td>12483</td></tr><tr><td>Madame Bovary</td><td>12483</td></tr><tr><td>A Room with a View</td><td>12483</td></tr><tr><td>Cryptonomicon</td><td>12483</td></tr><tr><td>The Complete Sherlock Holmes, Vol 2</td><td>12483</td></tr><tr><td>Tropic of Cancer</td><td>12483</td></tr><tr><td>The New York Trilogy</td><td>12483</td></tr><tr><td>Metamorphoses</td><td>12483</td></tr><tr><td>Founding Brothers: The Revolutionary Generation</td><td>12483</td></tr><tr><td>Peter and the Shadow Thieves (Peter and the Starcatchers, #2)</td><td>12483</td></tr><tr><td>The Salmon of Doubt (Dirk Gently, #3)</td><td>12483</td></tr><tr><td>Jailbird</td><td>12483</td></tr><tr><td>The Broken Wings</td><td>12483</td></tr></table>
